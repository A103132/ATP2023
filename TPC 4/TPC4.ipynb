# %%
l=[]
while menu != 0:
    menu = int(input(print("""Selecione o modo da sua lista:\n1-Criar Lista\n2-Ler Lista\n0-Sair""")))
    print("\n")

    if menu == 1:
        def crialista(N):
            print("Selecionou a criar lista")
            import random
            i=0 
            while i < N:
                l.append(random.randrange(0, 101))
                i += 1 
            return l
        N = int(input(print("Quantos números a lista vai ter?")))
        l = crialista(N)
        print(l)
       
    elif menu == 2:
        print("Selecionou ler lista")
        def leLista(N):
            l = []
            a = 1
            while N > 0:
                x = int(input("Insira um número " + str(a) + " :"))
                l.append(x)
                a = a + 1
                N = N - 1
            return l

        N = int(input(print("Quantos números a lista vai ter?")))
        print("Escolha os numeros") 
        l = leLista(N)
        print(l)

    print("\n")
    opçao = int(input(print("""Selecione a sua ação na lista:\n3-Soma\n4-Média\n5-Maior\n6-Menor\n7-Ordenada por ordem crescente\n8-Ordenada por ordem decrescente?\n9-Procura um elemento""")))
    print("\n")
    if opçao == 3:
        print("Selecionou a opção 3.")
        def somaLista(lista):
            soma = 0
            for n in lista:
                soma = soma + n
        
            return soma
        str(somaLista(l))
        print("A soma de todos os elementos é: "+ str(somaLista(l)) + "")
        break

    if opçao == 4:
        print("Selecionou a opção 4.")
        def mediaLista(lista):
            soma = 0
            for n in lista:
                soma = soma + n
                media = soma/len(lista)
            return media
        str(mediaLista(l))
        print("A media é: "+ str(mediaLista(l)) + "")
        break

    if opçao == 5:
        print("Selecionou a opção 5.")
        def maiorLista(lista):
            maior = lista[0]
            for n in lista[1:]:
                if n > maior:
                    maior = n 
        
            return maior
        str(maiorLista(l))
        print("A maior numero da lista é: "+ str(maiorLista(l)) + "")
        break
        

    if opçao == 6:
        print("Selecionou a opção 6.")
        def menorLista(lista):
            menor = lista[0]
            for n in lista[1:]:
                if n < menor:
                    menor = n 
        
            return menor
        str(menorLista(l))
        print("A menor numero da lista é: "+ str(menorLista(l)) + "")
        break
        

    if opçao == 7:
        print("A lista esta ordenada de forma crescente?")
        def estaOrdenada(lista):
            tam = len(lista)
            for i in range(len(lista) - 1):
                if lista[i] > lista[i + 1]:
                    return False
            return True

        print(estaOrdenada(l))
        break

    if opçao == 8:
        print("A lista esta ordenada de forma decrescente?")
        def estaOrdenada(lista):
            tam = len(lista)
            for i in range(len(lista) - 1):
                if lista[i] < lista[i + 1]:
                    return False
            return True

        print(estaOrdenada(l))
        break

    if opçao == 9:
        print("Selecionou a opção 9")
        def unicos(lista, elem):
            for n in lista:
                if elem in lista:
                    i = lista.index(elem)
                elif elem not in lista:
                    i = -1

            return "O índice do elemento na lista é " + str(i)

        elem = int(input("Que elemento quer encontrar?"))
        print (unicos(l, elem))
        break
# Out:
# Selecione o modo da sua lista:
# 1-Criar Lista
# 2-Ler Lista
# 0-Sair
# Selecionou ler lista
# Quantos números a lista vai ter?
# Escolha os numeros
# [1, 2, 3, 4, 5]
#
#
# Selecione a sua ação na lista:
# 3-Soma
# 4-Média
# 5-Maior
# 6-Menor
# 7-Ordenada por ordem crescente
# 8-Ordenada por ordem decrescente?
# 9-Procura um elemento
#
#
# Selecionou a opção 5.
# A maior numero da lista é: 5
